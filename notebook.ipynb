# %% [markdown]
# ![mkxspacehub](https://imgur.com/8NyvNQe.png)

# %% [markdown]
# #  MKX | Jupyter
#
# Codes samples written in Python through Jupyter Notebook in preparation for data science, machine learning and beyond.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import time
from ipywidgets import interact
from mpl_toolkits.mplot3d import Axes3D
sns.set_theme(style="darkgrid")

# %%
@interact(x=(0, 32))

def square(x):
    print("The square of {} is {}".format(x, x**2))
# Out:
# interactive(children=(IntSlider(value=16, description='x', max=32), Output()), _dom_classes=('widget-interact'…

# %%
a = np.linspace(0, 64, 256)

plt.plot(a, np.cos(a))
plt.title("Cosine")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
@interact(frequency=(1, 10, 1), amplitude=(1, 5, 0.1))
def plot_sine_wave(frequency, amplitude):
    x = np.linspace(0, 10, 1000)
    y = amplitude * np.sin(frequency * x)
    plt.plot(x, y)
    plt.title('Sine Wave')
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.show()
# Out:
# interactive(children=(IntSlider(value=5, description='frequency', max=10, min=1), FloatSlider(value=3.0, descr…

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.random.standard_normal(100)
y = np.random.standard_normal(100)
z = np.random.standard_normal(100)

ax.scatter(x, y, z)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
